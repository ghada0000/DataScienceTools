# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# Data science is an interdisciplinary field that uses various tools, technologies, and methodologies to extract meaningful insights from large and complex datasets. The data science ecosystem comprises a range of tools designed for different stages of the data workflow, including data collection, cleaning, analysis, visualization, and machine learning.

# %% [markdown]
# __Objectives__:
# - List of programming languages in data science
# - Most commonly used libraries in data science
# - Most popular data science tools
# - Arithmetic expression examples in Python

# %% [markdown]
# #### Here are some of the most commonly used programming languages in data science:
#
# * Python
# * R
# * SQL
# * Java
# * Scala
# * Julia
# * SAS
# * MATLAB
# * JavaScript
# * C++

# %% [markdown]
# #### Here are some of the most commonly used libraries in data science:
#
# **Python Libraries** :
#  * Pandas (For data manipulation and analysis)
#  * NumPy (For numerical computations)
#  * Matplotlib  (For data visualization)
#  * Seaborn (For statistical data visualization)
#  * SciPy  (For scientific and technical computing)
#  * Scikit (learn (For machine learning)
#  * TensorFlow (For deep learning and neural networks)
#
# **R Libraries**:
#  * ggplot2 (For data visualization)
#  * dplyr (For data manipulation)
#  * tidyr ( For data cleaning)
#  * caret ( For machine learning)
#  * shiny ( For building web applications for data analysis)
#  * stringr (For string manipulation)
#  * randomForest ( For building random forest models)
#  * data.table ( For fast data manipulation)
#
# These libraries are crucial for tasks such as data cleaning, analysis, visualization, and building machine learning models.

# %% [markdown]
# ####  the table below listed the most popular data science tools used across various stages of data processing and analysis:
# | Tool Name | Description |
# | --- | --- |
# | **Jupyter Notebooks** | Interactive environment for writing code, visualizing data, and documenting analysis. |
# |**RStudio**|Integrated development environment (IDE) for R programming.|
# |**Apache Hadoop**|Framework for distributed storage and processing of large datasets.|
# |**Apache Spark**|Unified analytics engine for large-scale data processing.|
# |**Tableau**|Data visualization and business intelligence tool.|
# |**IBM Watson Studio**|Data science and machine learning platform by IBM.|
# |**RapidMiner**| Data science platform for machine learning and data preparation.|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:

# %%
# This a simple arithmetic expression to mutiply then add integers
(5*2)+10
# Out:
# 20

# %%
# This will convert 180 minutes to hours by diving by 60
180/60
# Out:
# 3.0

# %% [markdown]
# -----

# %% [markdown]
# ## Author:
# Ghadah Alhamid

# %% [markdown]
# ### Screenshot:
# ![NoteBookScreenshot .png](attachment:e5c367ae-8db7-4302-85a7-7123bf1e496c.png)
